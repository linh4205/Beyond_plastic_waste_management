# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
dfgdp = pd.read_csv('gdp.csv')

# %%
dfgdp
# Out:
#                     Country Name Code          1960          1961  \
# 0                          Aruba  ABW           NaN           NaN
# 1    Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10
# 2                    Afghanistan  AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central  AFW  1.040428e+10  1.112805e+10
# 4                         Angola  AGO           NaN           NaN
# ..                           ...  ...           ...           ...
# 261                       Kosovo  XKX           NaN           NaN
# 262                  Yemen, Rep.  YEM           NaN           NaN
# 263                 South Africa  ZAF  7.575397e+09  7.972997e+09
# 264                       Zambia  ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe  ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
list[dfgdp]
# Out:
# list[                    Country Name Code          1960          1961  \
# 0                          Aruba  ABW           NaN           NaN
# 1    Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10
# 2                    Afghanistan  AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central  AFW  1.040428e+10  1.112805e+10
# 4                         Angola  AGO           NaN           NaN
# ..                           ...  ...           ...           ...
# 261                       Kosovo  XKX           NaN           NaN
# 262                  Yemen, Rep.  YEM           NaN           NaN
# 263                 South Africa  ZAF  7.575397e+09  7.972997e+09
# 264                       Zambia  ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe  ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
dfgdp = pd.read_csv('gdp.csv')
columns_to_keep = ['Country Name', 'Code'] + [str(year) for year in range(2000, 2021)]
filtered_dfgdp = dfgdp[columns_to_keep]

# Save the filtered data to the current directory
output_file_path = 'filtered_dfgdp_2000_2020.csv' 
filtered_dfgdp.to_csv(output_file_path, index=False)

# %%
gdp = pd.read_csv('filtered_dfgdp_2000_2020.csv')
gdp
# Out:
#                     Country Name Code          2000          2001  \
# 0                          Aruba  ABW  1.873453e+09  1.920112e+09
# 1    Africa Eastern and Southern  AFE  2.839525e+11  2.588432e+11
# 2                    Afghanistan  AFG           NaN           NaN
# 3     Africa Western and Central  AFW  1.404080e+11  1.480120e+11
# 4                         Angola  AGO  9.129635e+09  8.936064e+09
# ..                           ...  ...           ...           ...
# 261                       Kosovo  XKX           NaN           NaN
# 262                  Yemen, Rep.  YEM  9.652436e+09  9.861560e+09
# 263                 South Africa  ZAF  1.517534e+11  1.354296e+11
# 264                       Zambia  ZMB  3.600683e+09  4.094481e+09
# 265                     Zimbabwe  ZWE  6.689958e+09  6.777385e+09
#
#              2002          2003          2004          2005          2006  \
# 0    1.941341e+09  2.021229e+09  2.228492e+09  2.330726e+09  2.424581e+09
# ...

# %%
gdp_cap = pd.read_csv("gdp_per_capita.csv")

columns_to_keep = ['Country Name', 'Code'] + [str(year) for year in range(2000, 2021)]
filtered_dfgdp = gdp_cap[columns_to_keep]

# Save the filtered data to the current directory
output_file_path = 'gdp_capita_2000_2020.csv' 
filtered_dfgdp.to_csv(output_file_path, index=False)

dgp_cap =pd.read_csv("gdp_per_capita.csv")
gdp_cap
# Out:
#                     Country Name Code        1960        1961        1962  \
# 0                          Aruba  ABW         NaN         NaN         NaN
# 1    Africa Eastern and Southern  AFE  147.612227  147.014904  156.189192
# 2                    Afghanistan  AFG   59.773234   59.860900   58.458009
# 3     Africa Western and Central  AFW  107.932233  113.081647  118.831107
# 4                         Angola  AGO         NaN         NaN         NaN
# ..                           ...  ...         ...         ...         ...
# 261                       Kosovo  XKX         NaN         NaN         NaN
# 262                  Yemen, Rep.  YEM         NaN         NaN         NaN
# 263                 South Africa  ZAF  443.009920  454.962013  473.011405
# 264                       Zambia  ZMB  232.188564  220.042067  212.578449
# 265                     Zimbabwe  ZWE  278.813847  280.828663  276.688233
#
#            1963        1964        1965        1966        1967  ...  \
# ...

# %%
country_list = dfgdp['Country Name']. tolist()
country_list
# Out:
# ['Aruba',
#  'Africa Eastern and Southern',
#  'Afghanistan',
#  'Africa Western and Central',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
# ...

# %%
code = dfgdp['Code']. tolist()
code
# Out:
# ['ABW',
#  'AFE',
#  'AFG',
#  'AFW',
#  'AGO',
#  'ALB',
#  'AND',
#  'ARB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'ASM',
#  'ATG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BHS',
#  'BIH',
#  'BLR',
#  'BLZ',
#  'BMU',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BTN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CEB',
#  'CHE',
#  'CHI',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'COM',
#  'CPV',
#  'CRI',
#  'CSS',
#  'CUB',
#  'CUW',
#  'CYM',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DMA',
#  'DNK',
#  'DOM',
#  'DZA',
#  'EAP',
#  'EAR',
#  'EAS',
#  'ECA',
#  'ECS',
#  'ECU',
#  'EGY',
#  'EMU',
#  'ERI',
#  'ESP',
#  'EST',
#  'ETH',
#  'EUU',
#  'FCS',
#  'FIN',
#  'FJI',
#  'FRA',
#  'FRO',
#  'FSM',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIB',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GRD',
#  'GRL',
#  'GTM',
#  'GUM',
#  'GUY',
#  'HIC',
#  'HKG',
#  'HND',
#  'HPC',
#  'HRV',
# ...

# %%
world = gdp[gdp['Country Name'] == 'World']

# Extract the years (2000-2020) and corresponding values
years = world.columns[2:]  # Skip the first three columns (Country Name, Code, and year labels)
values = world.iloc[0, 2:]  # Values for countries (ignoring Country Name and Code)



plt.figure(figsize=(10, 6))
plt.plot(years, values, marker='o', color='b', label='World')

plt.title('Word GDP (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (in billions in US dollar)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)

plt.legend()
plt.tight_layout()
plt.show()

# %%
oceania = [
    'American Samoa','Australia','Fiji','Kiribati','Marshall Islands','Micronesia, Fed. Sts.','Nauru',
    'New Caledonia','New Zealand','Palau','Papua New Guinea','Solomon Islands','Tonga','Tuvalu','Vanuatu','Samoa'
]

oceania
# Out:
# ['American Samoa',
#  'Australia',
#  'Fiji',
#  'Kiribati',
#  'Marshall Islands',
#  'Micronesia, Fed. Sts.',
#  'Nauru',
#  'New Caledonia',
#  'New Zealand',
#  'Palau',
#  'Papua New Guinea',
#  'Solomon Islands',
#  'Tonga',
#  'Tuvalu',
#  'Vanuatu',
#  'Samoa']

# %%
oceania_data = gdp[gdp['Country Name'].isin(oceania)]

# %%
print(oceania_data)
# Out:
#               Country Name Code          2000          2001          2002  \
# 11          American Samoa  ASM           NaN           NaN  5.120000e+08
# 13               Australia  AUS  4.155762e+11  3.790839e+11  3.953427e+11
# 76                    Fiji  FJI  1.678239e+09  1.652464e+09  1.833280e+09
# 79   Micronesia, Fed. Sts.  FSM  2.332718e+08  2.409709e+08  2.425172e+08
# 124               Kiribati  KIR  6.725417e+07  6.310127e+07  7.219646e+07
# 155       Marshall Islands  MHL  1.153475e+08  1.228240e+08  1.317382e+08
# 172          New Caledonia  NCL  3.420032e+09  3.297735e+09  3.740057e+09
# 179                  Nauru  NRU           NaN           NaN           NaN
# 180            New Zealand  NZL  5.262328e+10  5.387243e+10  6.662773e+10
# 188                  Palau  PLW  1.462975e+08  1.569079e+08  1.631849e+08
# 189       Papua New Guinea  PNG  3.521340e+09  3.081024e+09  2.999511e+09
# 209        Solomon Islands  SLB  4.199336e+08  4.094354e+08  3.464320e+08
# ...

# %%
#179 Naruru has many Nan data > need to be deleted

oceania_c = [
    'American Samoa','Australia','Fiji','Kiribati','Marshall Islands','Micronesia, Fed. Sts.',
    'New Caledonia','New Zealand','Palau','Papua New Guinea','Solomon Islands','Tonga','Tuvalu','Vanuatu','Samoa'
]

oceania_dc = gdp[gdp['Country Name'].isin(oceania_c)]

# %%
print(oceania_dc)
# Out:
#               Country Name Code          2000          2001          2002  \
# 11          American Samoa  ASM           NaN           NaN  5.120000e+08
# 13               Australia  AUS  4.155762e+11  3.790839e+11  3.953427e+11
# 76                    Fiji  FJI  1.678239e+09  1.652464e+09  1.833280e+09
# 79   Micronesia, Fed. Sts.  FSM  2.332718e+08  2.409709e+08  2.425172e+08
# 124               Kiribati  KIR  6.725417e+07  6.310127e+07  7.219646e+07
# 155       Marshall Islands  MHL  1.153475e+08  1.228240e+08  1.317382e+08
# 172          New Caledonia  NCL  3.420032e+09  3.297735e+09  3.740057e+09
# 180            New Zealand  NZL  5.262328e+10  5.387243e+10  6.662773e+10
# 188                  Palau  PLW  1.462975e+08  1.569079e+08  1.631849e+08
# 189       Papua New Guinea  PNG  3.521340e+09  3.081024e+09  2.999511e+09
# 209        Solomon Islands  SLB  4.199336e+08  4.094354e+08  3.464320e+08
# 239                  Tonga  TON  2.048496e+08  1.811170e+08  1.827637e+08
# ...

# %%
means = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    mean_value = oceania_dc[year].mean()
    means[year] = mean_value


for year, means in means.items():
    print(f"Mean GDP for {year}: {means}")
# Out:
# Mean GDP for 2000: 34182916718.388863
# Mean GDP for 2001: 31621867858.102753
# Mean GDP for 2002: 31517350172.631443
# Mean GDP for 2003: 37917682658.81855
# Mean GDP for 2004: 48879074461.22725
# Mean GDP for 2005: 55112720523.5182
# Mean GDP for 2006: 58699674722.65146
# Mean GDP for 2007: 67745006731.67834
# Mean GDP for 2008: 81074559882.00804
# Mean GDP for 2009: 71752603014.62746
# Mean GDP for 2010: 88320938921.06729
# Mean GDP for 2011: 106850183872.35005
# Mean GDP for 2012: 117493327140.15288
# Mean GDP for 2013: 120512821223.38414
# Mean GDP for 2014: 114161907673.59003
# Mean GDP for 2015: 104577745013.39212
# Mean GDP for 2016: 95675988951.89404
# Mean GDP for 2017: 105097628942.2226
# Mean GDP for 2018: 112392194394.97482
# Mean GDP for 2019: 110013576704.2488
# Mean GDP for 2020: 112380770069.41458

# %%
type(means)
# Out:
# numpy.float64

# %%
#manually create the dataset of the mean
# the issue of float 64 numphy

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = oceania_dc[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 270517201.689131
# Median GDP for 2001: 265507619.442065
# Median GDP for 2002: 288078881.433056
# Median GDP for 2003: 338838639.378435
# Median GDP for 2004: 397611126.698465
# Median GDP for 2005: 465568018.300557
# Median GDP for 2006: 493000000.0
# Median GDP for 2007: 518000000.0
# Median GDP for 2008: 590748237.021657
# Median GDP for 2009: 592622502.360859
# Median GDP for 2010: 663155954.963744
# Median GDP for 2011: 737147951.052999
# Median GDP for 2012: 747839697.746593
# Median GDP for 2013: 758304466.245339
# Median GDP for 2014: 756805940.214677
# Median GDP for 2015: 730870581.672312
# Median GDP for 2016: 780889605.899977
# Median GDP for 2017: 832025573.983795
# Median GDP for 2018: 821286927.535723
# Median GDP for 2019: 852007112.724637
# Median GDP for 2020: 758050410.3240659

# %%
oce_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])


plt.figure(figsize=(10, 6))
plt.plot(oce_df['Year'], oce_df['Median GDP'], marker='o', color='b', label='Median GDP of Oceania')


plt.title('Median GDP of Oceania Countries (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()
plt.show()

# %%
oceania_dc.sort_values(
    by='2019',
    ascending=True
).head(20)
# Out:
#               Country Name Code          2000          2001          2002  \
# 245                 Tuvalu  TUV  1.374206e+07  1.319654e+07  1.545099e+07
# 124               Kiribati  KIR  6.725417e+07  6.310127e+07  7.219646e+07
# 155       Marshall Islands  MHL  1.153475e+08  1.228240e+08  1.317382e+08
# 188                  Palau  PLW  1.462975e+08  1.569079e+08  1.631849e+08
# 79   Micronesia, Fed. Sts.  FSM  2.332718e+08  2.409709e+08  2.425172e+08
# 239                  Tonga  TON  2.048496e+08  1.811170e+08  1.827637e+08
# 11          American Samoa  ASM           NaN           NaN  5.120000e+08
# 260                  Samoa  WSM  2.690197e+08  2.730884e+08  2.880789e+08
# 258                Vanuatu  VUT  2.720147e+08  2.579269e+08  2.625966e+08
# 209        Solomon Islands  SLB  4.199336e+08  4.094354e+08  3.464320e+08
# 76                    Fiji  FJI  1.678239e+09  1.652464e+09  1.833280e+09
# 172          New Caledonia  NCL  3.420032e+09  3.297735e+09  3.740057e+09
# ...

# %%
oceania_dc = oceania_dc.fillna(0)  # Or you can use dropna() to remove rows with NaN values

# Set the year columns as index for better plotting
year_columns = [str(year) for year in range(2000, 2021)]
oceania_dc_years = oceania_dc[["Country Name"] + year_columns]

# Reshape the data to have 'Country Name' as one column and years as another
oceania_dc_long = oceania_dc_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

# Convert GDP to numeric (in case there are non-numeric values like 'NaN')
oceania_dc_long["GDP"] = pd.to_numeric(oceania_dc_long["GDP"], errors='coerce')

# Plot the GDP data for each country over time
plt.figure(figsize=(15, 8))
sns.lineplot(data=oceania_dc_long, x="Year", y="GDP", hue="Country Name", marker="o")


plt.title('GDP of Countries in Oceania (2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()
plt.show()

# %%
# List of Asian countries excluding China, India, and MENA countries
asian_countries = [
    "Japan", "Mongolia", "North Korea", "South Korea", "Taiwan",  # East Asia
    "Brunei", "Cambodia", "East Timor", "Indonesia", "Laos", "Malaysia",
    "Myanmar", "Philippines", "Singapore", "Thailand", "Vietnam",  # Southeast Asia
    "Kazakhstan", "Kyrgyzstan", "Tajikistan", "Turkmenistan", "Uzbekistan",  # Central Asia
    "Afghanistan", "Bangladesh", "Bhutan", "Maldives", "Nepal", "Pakistan", "Sri Lanka"  # South Asia
]


filtered_gdp = dfgdp[dfgdp['Country Name'].isin(asian_countries)]

# Display the filtered DataFrame
filtered_gdp
# Out:
#      Country Name Code          1960          1961          1962  \
# 2     Afghanistan  AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 20     Bangladesh  BGD  4.274894e+09  4.817580e+09  5.081413e+09
# 32         Bhutan  BTN           NaN           NaN           NaN
# 106     Indonesia  IDN           NaN           NaN           NaN
# 119         Japan  JPN  4.430734e+10  5.350862e+10  6.072302e+10
# 120    Kazakhstan  KAZ           NaN           NaN           NaN
# 123      Cambodia  KHM  6.371429e+08  6.428571e+08  6.600000e+08
# 138     Sri Lanka  LKA  1.409874e+09  1.444328e+09  1.434156e+09
# 152      Maldives  MDV           NaN           NaN           NaN
# 160       Myanmar  MMR           NaN  5.843514e+08  6.125173e+08
# 163      Mongolia  MNG           NaN           NaN           NaN
# 169      Malaysia  MYS  1.916242e+09  1.901869e+09  2.001503e+09
# 178         Nepal  NPL  5.083344e+08  5.319596e+08  5.740911e+08
# ...

# %%
asia = ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Bhutan', 'Brunei Darussalam', 'Georgia', 'Indonesia', 
'Japan', 'Kazakhstan', 'Cambodia', 'Kyrgyz Republic', "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Lao PDR', 'Maldives', 'Malaysia', 
'Mongolia', 'Myanmar', 'Nepal', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Tajikistan', 'Turkmenistan', 'Timor-Leste', 
'Uzbekistan', 'Vietnam']

asia_data = dfgdp[dfgdp['Country Name'].isin(asia)]

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = asia_data[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 6001153306.2645
# Median GDP for 2001: 6007055042.17687
# Median GDP for 2002: 6080754480.175905
# Median GDP for 2003: 6917043489.66054
# Median GDP for 2004: 8276351811.531784
# Median GDP for 2005: 10059917958.364006
# Median GDP for 2006: 11666859658.68515
# Median GDP for 2007: 14127673823.94935
# Median GDP for 2008: 21142269505.4551
# Median GDP for 2009: 24834775779.799103
# Median GDP for 2010: 30189605416.7323
# Median GDP for 2011: 41675967654.064
# Median GDP for 2012: 46741444085.63251
# Median GDP for 2013: 49884899115.5611
# Median GDP for 2014: 53394551196.684906
# Median GDP for 2015: 44437042385.8788
# Median GDP for 2016: 37018473764.31305
# Median GDP for 2017: 39395922313.3362
# Median GDP for 2018: 43939184873.9496
# Median GDP for 2019: 46702831932.7731
# Median GDP for 2020: 42607176470.5882

# %%
year_columns = [str(year) for year in range(2000, 2021)]
asia_data_years = asia_data[["Country Name"] + year_columns]

# Reshape the data to have 'Country Name' as one column and years as another
asia_data_long = asia_data_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

# Convert GDP to numeric (in case there are non-numeric values like 'NaN')
asia_data_long["GDP"] = pd.to_numeric(asia_data_long["GDP"], errors='coerce')

# Plot the GDP data for each country over time
plt.figure(figsize=(15, 8))
sns.lineplot(data=asia_data_long, x="Year", y="GDP", hue="Country Name", marker="o")


plt.title('GDP of Countries in Asia (2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()

# %%
asi_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])

plt.figure(figsize=(10, 6))
plt.plot(asi_df['Year'], asi_df['Median GDP'], marker='o', color='r', label='Median GDP of Asia')


plt.title('Median GDP of Asian Countries (excl. China and India) (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()
plt.show()

# %%
china = gdp[gdp['Country Name'] == 'China']

# Extract the years (2000-2020) and corresponding values
china_years = china.columns[3:]  # Skip the first three columns (Country Name, Code, and year labels)
china_values = china.iloc[0, 3:]  # Values for countries (ignoring Country Name and Code)



plt.figure(figsize=(10, 6))
plt.plot(china_years, china_values, marker='o', color='r', label='China')

plt.title('China GDP (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)

plt.legend()
plt.tight_layout()
plt.show()

# %%
china
# Out:
#    Country Name Code          2000          2001          2002          2003  \
# 40        China  CHN  1.211347e+12  1.339396e+12  1.470550e+12  1.660288e+12
#
#             2004          2005          2006          2007  ...          2011  \
# 40  1.955347e+12  2.285966e+12  2.752132e+12  3.550343e+12  ...  7.551500e+12
#
#             2012          2013          2014          2015          2016  \
# 40  8.532230e+12  9.570406e+12  1.047568e+13  1.106155e+13  1.123328e+13
#
#             2017          2018          2019          2020
# 40  1.231041e+13  1.389482e+13  1.427994e+13  1.472273e+13
#
# [1 rows x 23 columns]

# %%
india = gdp[gdp['Country Name'] == 'India']

# Extract the years (2000-2020) and corresponding values
india_years = india.columns[2:]  # Skip the first three columns (Country Name, Code, and year labels)
india_values = india.iloc[0, 2:]  # Values for countries (ignoring Country Name and Code)



plt.figure(figsize=(10, 6))
plt.plot(india_years, india_values, marker='o', color='b', label='India')

plt.title('India GDP (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)

plt.legend()
plt.tight_layout()
plt.show()

# %%
europe_c = [
    'Austria','Belgium','Bulgaria','Croatia','Republic of Cyprus','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 
    'Portugal', 'Romania', 'Slovakia', 'Slovenia','Spain','Sweden'
]

europe_dc = gdp[gdp['Country Name'].isin(europe_c)]

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = europe_dc[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 118310710337.203
# Median GDP for 2001: 121498889485.459
# Median GDP for 2002: 134156091661.961
# Median GDP for 2003: 164862142212.19
# Median GDP for 2004: 194015335237.149
# Median GDP for 2005: 204809103345.355
# Median GDP for 2006: 216907539831.891
# Median GDP for 2007: 256052559540.104
# Median GDP for 2008: 274326912260.144
# Median GDP for 2009: 243701635176.438
# Median GDP for 2010: 237880908317.652
# Median GDP for 2011: 244797226567.109
# Median GDP for 2012: 225509709550.982
# Median GDP for 2013: 238211547205.677
# Median GDP for 2014: 235144949470.797
# Median GDP for 2015: 199313894327.486
# Median GDP for 2016: 206286022781.894
# Median GDP for 2017: 220811110492.149
# Median GDP for 2018: 248950103352.137
# Median GDP for 2019: 252498032247.163
# Median GDP for 2020: 248715551366.635

# %%
eu_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])


plt.figure(figsize=(10, 6))
plt.plot(eu_df['Year'], eu_df['Median GDP'], marker='o', color='b', label='Median GDP of Europe')


plt.title('Median GDP of Europe Countries (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()
plt.show()

# %%
europe_dc = europe_dc.fillna(0)  

year_columns = [str(year) for year in range(2000, 2021)]
europe_dc_years = europe_dc[["Country Name"] + year_columns]

# Reshape the data to have 'Country Name' as one column and years as another
europe_dc_long = europe_dc_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

# Convert GDP to numeric (in case there are non-numeric values like 'NaN')
europe_dc_long["GDP"] = pd.to_numeric(europe_dc_long["GDP"], errors='coerce')

# Plot the GDP data for each country over time
plt.figure(figsize=(15, 8))
sns.lineplot(data=europe_dc_long, x="Year", y="GDP", hue="Country Name", marker="o")


plt.title('GDP of Countries in Europe (2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()
plt.show()

# %%
africa = [ 'South Africa','Nigeria', 'Congo (gold)', 'Sudan', 
          'Garner', 'Zimbabwe', 'Senegal', 'Kenya', 'Zambia', 'Madagascar', 'Cameroon',
          "C ô te d'Ivoire'", 'Niger', 'Uganda','Burkina Faso', 'Sierra Leone', 
          'Chad', 'Benin', 'Burundi','Liberia', 'Somalia', 'Malawi', 'Gabon',
          'Congo (Brazzaville)', 'Togo', 'Rwanda', 'Central Africa', 'Mauritania',
          'Eswatini', 'Lesotho', 'Botswana', 'Seychelles' ]
africa_data = gdp[gdp['Country Name'].isin(africa)]

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = africa_data[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 3244180658.975965
# Median GDP for 2001: 3428296825.27676
# Median GDP for 2002: 3908097941.05814
# Median GDP for 2003: 4821304043.247725
# Median GDP for 2004: 5258210792.077945
# Median GDP for 2005: 6002811295.58918
# Median GDP for 2006: 6471566262.968121
# Median GDP for 2007: 7897385906.800964
# Median GDP for 2008: 9619585892.48879
# Median GDP for 2009: 9533788453.49037
# Median GDP for 2010: 10046165151.198025
# Median GDP for 2011: 11816058130.852951
# Median GDP for 2012: 11973169282.79335
# Median GDP for 2013: 12517845732.2095
# Median GDP for 2014: 13284528654.0574
# Median GDP for 2015: 11323020828.5844
# Median GDP for 2016: 11821066152.5979
# Median GDP for 2017: 12701654743.2149
# Median GDP for 2018: 13760033096.5122
# Median GDP for 2019: 14104664514.87
# Median GDP for 2020: 13741378450.136

# %%
africa_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])


plt.figure(figsize=(10, 6))
plt.plot(africa_df['Year'], africa_df['Median GDP'], marker='o', color='b', label='Median GDP of Africa')


plt.title('Median GDP of Sub-Saharan Africa Countries (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()
plt.show()

# %%
africa_data = africa_data.fillna(0) 
year_columns = [str(year) for year in range(2000, 2021)]
africa_data_years = africa_data[["Country Name"] + year_columns]
africa_data_long = africa_data_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")
africa_data_long["GDP"] = pd.to_numeric(africa_data_long["GDP"], errors='coerce')
plt.figure(figsize=(15, 8))
sns.lineplot(data=africa_data_long, x="Year", y="GDP", hue="Country Name", marker="o")

plt.title('GDP of Countries in Sub- Saharan African (2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# List of MENA countries
mena_countries = [
    "Bahrain", "Cyprus", "Egypt", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia",
    "Syria", "Turkey", "United Arab Emirates", "Yemen", "Algeria",
    "Libya", "Morocco", "Sudan", "Tunisia", "Western Sahara"
]

# Filter the gdp DataFrame for MENA countries
mena = gdp[gdp['Country Name'].isin(mena_countries)]

# Display the filtered DataFrame
print(mena)
# Out:
#              Country Name Code          2000          2001          2002  \
# 8    United Arab Emirates  ARE  1.043374e+11  1.033116e+11  1.098162e+11
# 22                Bahrain  BHR  9.062899e+09  8.976197e+09  9.593511e+09
# 53                 Cyprus  CYP  9.985844e+09  1.039790e+10  1.142023e+10
# 60                Algeria  DZA  5.479039e+10  5.474471e+10  5.676036e+10
# 113                  Iraq  IRQ  4.836425e+10  3.617643e+10  3.292845e+10
# 115                Israel  ISR  1.324557e+11  1.308163e+11  1.211485e+11
# 118                Jordan  JOR  8.460424e+09  8.975690e+09  9.582453e+09
# 127                Kuwait  KWT  3.771284e+10  3.488751e+10  3.813755e+10
# 130               Lebanon  LBN  1.726036e+10  1.764975e+10  1.915224e+10
# 132                 Libya  LBY  3.827021e+10  3.411006e+10  2.048189e+10
# 148               Morocco  MAR  3.885725e+10  3.945958e+10  4.223684e+10
# 182                  Oman  OMN  1.950745e+10  1.945200e+10  2.014276e+10
# ...

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = mena[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 37712842242.5033
# Median GDP for 2001: 34110064452.1567
# Median GDP for 2002: 23142153759.5836
# Median GDP for 2003: 26265625000.0
# Median GDP for 2004: 33122307692.3077
# Median GDP for 2005: 47334148578.4164
# Median GDP for 2006: 60882142857.1429
# Median GDP for 2007: 79041294874.4553
# Median GDP for 2008: 92507257783.5697
# Median GDP for 2009: 92897320375.8176
# Median GDP for 2010: 93216746661.5977
# Median GDP for 2011: 101370474295.109
# Median GDP for 2012: 98266306615.3632
# Median GDP for 2013: 106825649872.108
# Median GDP for 2014: 110081248587.369
# Median GDP for 2015: 101179808076.36
# Median GDP for 2016: 103311649248.024
# Median GDP for 2017: 109682728023.112
# Median GDP for 2018: 118096227400.092
# Median GDP for 2019: 119870439113.662
# Median GDP for 2020: 105960225688.145

# %%
africa_data = mena.fillna(0) 
year_columns = [str(year) for year in range(2000, 2021)]
africa_data_years = africa_data[["Country Name"] + year_columns]
africa_data_long = africa_data_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")
africa_data_long["GDP"] = pd.to_numeric(africa_data_long["GDP"], errors='coerce')
plt.figure(figsize=(15, 8))
sns.lineplot(data=africa_data_long, x="Year", y="GDP", hue="Country Name", marker="o")

plt.title('GDP of Countries in Middle East and North Africa(2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
mena_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])


plt.figure(figsize=(10, 6))
plt.plot(mena_df['Year'], mena_df['Median GDP'], marker='o', color='b', label='Median GDP of Africa')


plt.title('Median GDP of Middle East and North Africa Countries (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()

# %%
america_data = ['Aruba', 'Argentina', 'American Samoa', 'Antigua and Barbuda', 'Bahamas, The', 'Barbados', 
'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands', 
'Dominica', 'Dominican Republic', 'Ecuador', 'El Salvador', 'French Polynesia', 'Grenada', 'Guatemala', 'Guyana', 'Honduras', 
'Jamaica', 'Mexico', 'Panama', 'Paraguay', 'Peru', 'Puerto Rico', 'St. Kitts and Nevis', 'St. Lucia', 'St. Vincent and the Grenadines', 
'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela, RB']
america_data = gdp[gdp['Country Name'].isin(america_data)]

# %%
medians = {}

years = [str(year) for year in range(2000, 2021)]

for year in years:
    median_value = america_data[year].median()
    medians[year] = median_value


for year, median in medians.items():
    print(f"Median GDP for {year}: {median}")
# Out:
# Median GDP for 2000: 8930384807.2443
# Median GDP for 2001: 9194717835.99985
# Median GDP for 2002: 9363645823.431622
# Median GDP for 2003: 10367845183.2691
# Median GDP for 2004: 11727469988.4915
# Median GDP for 2005: 12970934242.871399
# Median GDP for 2006: 13429430050.261
# Median GDP for 2007: 17011750000.0
# Median GDP for 2008: 17986890000.0
# Median GDP for 2009: 17601620000.0
# Median GDP for 2010: 19649631314.0482
# Median GDP for 2011: 22123406715.2977
# Median GDP for 2012: 23574685053.50255
# Median GDP for 2013: 24629719282.27735
# Median GDP for 2014: 25104656549.047447
# Median GDP for 2015: 23438240000.0
# Median GDP for 2016: 22386264807.3174
# Median GDP for 2017: 22975415842.4648
# Median GDP for 2018: 23900438563.7271
# Median GDP for 2019: 25906091424.5772
# Median GDP for 2020: 24150475816.956947

# %%
ame_df = pd.DataFrame(list(medians.items()), columns=['Year', 'Median GDP'])


plt.figure(figsize=(10, 6))
plt.plot(ame_df['Year'], ame_df['Median GDP'], marker='o', color='b', label='Median GDP of North America')


plt.title('Median GDP of American Countries(excl.USA) (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)


plt.legend()
plt.tight_layout()
plt.show()

# %%
Americas_dc = america_data.fillna(0)  # Or you can use dropna() to remove rows with NaN values

# Set the year columns as index for better plotting
year_columns = [str(year) for year in range(2000, 2021)]
Americas_dc_years = Americas_dc[["Country Name"] + year_columns]

# Reshape the data to have 'Country Name' as one column and years as another
Americas_dc_long = Americas_dc_years.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

# Convert GDP to numeric (in case there are non-numeric values like 'NaN')
Americas_dc_long["GDP"] = pd.to_numeric(Americas_dc_long["GDP"], errors='coerce')

# Plot the GDP data for each country over time
plt.figure(figsize=(15, 8))
sns.lineplot(data=Americas_dc_long, x="Year", y="GDP", hue="Country Name", marker="o")


plt.title('GDP of Countries in American(excl.USA) (2000-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('GDP  (trillions)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()
plt.show()

# %%
us = gdp[gdp['Country Name'] == 'United States']

# Extract the years (2000-2020) and corresponding values
us_years = us.columns[3:]  # Skip the first three columns (Country Name, Code, and year labels)
us_values = us.iloc[0, 3:]  # Values for countries (ignoring Country Name and Code)



plt.figure(figsize=(10, 6))
plt.plot(years, values, marker='o', color='g', label='China')

plt.title('United States GDP (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (in billions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(False)

plt.legend()
plt.tight_layout()
plt.show()

# %%
#Converting the data of the Column in one Row

# Load the CSV file
file_path = "filtered_dfgdp_2000_2020.csv"
df_wide = pd.read_csv(file_path)

# Inspect the first few rows
print("Original Data:")
print(df_wide.head())

id_column = df_wide.columns[0]  

# Convert the individual year into one row
df_long = df_wide.melt(id_vars=[id_column], var_name="year", value_name="Value")

# Convert 'year' to integer
df_long["year"] = pd.to_numeric(df_long["year"], errors="coerce")

# Display a sample of the transformed dataset
print("\nTransformed Data:")
print(df_long.head(10))  # Show only the first 10 rows
# Out:
# Original Data:
#                   Country Name Code          2000          2001          2002  \
# 0                        Aruba  ABW  1.873453e+09  1.920112e+09  1.941341e+09
# 1  Africa Eastern and Southern  AFE  2.839525e+11  2.588432e+11  2.648950e+11
# 2                  Afghanistan  AFG           NaN           NaN  4.055180e+09
# 3   Africa Western and Central  AFW  1.404080e+11  1.480120e+11  1.769334e+11
# 4                       Angola  AGO  9.129635e+09  8.936064e+09  1.528559e+10
#
#            2003          2004          2005          2006          2007  ...  \
# 0  2.021229e+09  2.228492e+09  2.330726e+09  2.424581e+09  2.615084e+09  ...
# 1  3.526921e+11  4.388756e+11  5.122599e+11  5.759762e+11  6.612422e+11  ...
# 2  4.515559e+09  5.226779e+09  6.209138e+09  6.971286e+09  9.747880e+09  ...
# 3  2.046419e+11  2.540903e+11  3.105543e+11  3.932967e+11  4.617776e+11  ...
# 4  1.781271e+10  2.355205e+10  3.697092e+10  5.238101e+10  6.526645e+10  ...
#
# ...

# %%
gdp_long = df_long.dropna()
df_long["year"] = df_long["year"].astype(str).str.replace(".0", "", regex=False).astype(str)

# %%
#integrating all the GDP

# %%
plt.figure(figsize=(10, 6))

plt.plot(africa_df['Year'], africa_df['Median GDP'], marker='o', color='yellow', label='Median GDP of Africa')
plt.plot(ame_df['Year'], ame_df['Median GDP'], marker='o', color='green', label='Median GDP of North America')
plt.plot(eu_df['Year'], eu_df['Median GDP'], marker='o', color='blue', label='Median GDP of Europe')
plt.plot(asi_df['Year'], asi_df['Median GDP'], marker='o', color='orange', label='Median GDP of Asia')
plt.plot(oce_df['Year'], oce_df['Median GDP'], marker='o', color='brown', label='Median GDP of Oceania')

plt.plot(india_years, india_values, marker='^', color='black', label='GDP of India')
plt.plot(china_years, china_values, marker='x', color='red', label='GDP of China')
plt.plot(us_years, us_values,  marker='s', color='purple', label='GDP of the US')



plt.title('Median GDP by contnent (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions in US dollar)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))

plt.plot(africa_df['Year'], africa_df['Median GDP'], marker='o', color='yellow', label='Median GDP of Africa')
plt.plot(ame_df['Year'], ame_df['Median GDP'], marker='o', color='green', label='Median GDP of North America')
plt.plot(eu_df['Year'], eu_df['Median GDP'], marker='o', color='blue', label='Median GDP of Europe')
plt.plot(asi_df['Year'], asi_df['Median GDP'], marker='o', color='orange', label='Median GDP of Asia')
plt.plot(oce_df['Year'], oce_df['Median GDP'], marker='o', color='brown', label='Median GDP of Oceania')


plt.title('Median GDP by contnent excl. India, China and the US (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions in US dollar)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)

plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))

plt.plot(africa_df['Year'], africa_df['Median GDP'], marker='o', color='yellow', label='Median GDP of Africa')
plt.plot(ame_df['Year'], ame_df['Median GDP'], marker='o', color='green', label='Median GDP of North America')
plt.plot(asi_df['Year'], asi_df['Median GDP'], marker='o', color='orange', label='Median GDP of Asia')
plt.plot(oce_df['Year'], oce_df['Median GDP'], marker='o', color='brown', label='Median GDP of Oceania')


plt.title('Median GDP by contnent excl. India, China, the US and Europe (2000-2020)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median GDP (in billions in US dollar)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)

plt.tight_layout()

# %%
india
# Out:
#     Country Name Code          2000          2001          2002          2003  \
# 109        India  IND  4.683949e+11  4.854410e+11  5.149379e+11  6.076993e+11
#
#              2004          2005          2006          2007  ...  \
# 109  7.091485e+11  8.203816e+11  9.402599e+11  1.216735e+12  ...
#
#              2011          2012          2013          2014          2015  \
# 109  1.823050e+12  1.827638e+12  1.856722e+12  2.039127e+12  2.103588e+12
#
#              2016          2017          2018          2019          2020
# 109  2.294798e+12  2.651473e+12  2.701112e+12  2.870504e+12  2.660245e+12
#
# [1 rows x 23 columns]
