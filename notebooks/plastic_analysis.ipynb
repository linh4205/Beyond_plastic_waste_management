# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
df1= pd.read_csv("1- global-plastics-production.csv")

# %%
'''
df1-4: dataset from kaggle named "Plastic Pollution"
'''
# Out:
# '\ndf1-4: dataset from kaggle named "Plastic Pollution"\n'

# %%
list[df1]
# Out:
# list[   Entity      Code  Year  Annual plastic production between 1950 and 2019
# 0   World  OWID_WRL  1950                                          2000000
# 1   World  OWID_WRL  1951                                          2000000
# 2   World  OWID_WRL  1952                                          2000000
# 3   World  OWID_WRL  1953                                          3000000
# 4   World  OWID_WRL  1954                                          3000000
# ..    ...       ...   ...                                              ...
# 64  World  OWID_WRL  2015                                        381000000
# 65  World  OWID_WRL  2016                                        400050000
# 66  World  OWID_WRL  2017                                        420052500
# 67  World  OWID_WRL  2018                                        441055140
# 68  World  OWID_WRL  2019                                        459746020
#
# [69 rows x 4 columns]]

# %%
df1.describe()
# Out:
#               Year  Annual plastic production between 1950 and 2019
# count    69.000000                                     6.900000e+01
# mean   1984.652174                                     1.375638e+08
# std      20.460023                                     1.320418e+08
# min    1950.000000                                     2.000000e+06
# 25%    1967.000000                                     2.300000e+07
# 50%    1985.000000                                     9.000000e+07
# 75%    2002.000000                                     2.310000e+08
# max    2019.000000                                     4.597460e+08

# %%
df1_cleaned = df1.dropna()

# %%
plt.bar(df1_cleaned['Year'],df1_cleaned['Annual plastic production between 1950 and 2019'])
plt.title('Global plastic production')
plt.xlabel('Year')
plt.ylabel('global-plastics-production (hundred million kg per year)')
# Out:
# Text(0, 0.5, 'global-plastics-production (hundred million kg per year)')

# %%
# Add the missing year (1974) with a NaN value
data = df1.set_index('Year').reindex(range(1950, 2020)).reset_index()

# .interpolate(): Interpolate to fill the missing value for 1974
data['Annual plastic production between 1950 and 2019'] =data['Annual plastic production between 1950 and 2019'].interpolate()

print(data.loc[data['Year'] == 1974])
# Out:
#     Year Entity Code  Annual plastic production between 1950 and 2019
# 24  1974    NaN  NaN                                       48500000.0

# %%
plt.figseize =(10.6) 
plt.bar(data['Year'],data['Annual plastic production between 1950 and 2019'])
plt.title('Global plastic production (1950 - 2019)')
plt.xlabel('Year')
plt.ylabel('Plastics production (hundred million kg per year)')
plt.grid(False)

# %%
df1['Year'] == '1974'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Name: Year, Length: 69, dtype: bool

# %%
list[df1]
# Out:
# list[   Entity      Code  Year  Annual plastic production between 1950 and 2019
# 0   World  OWID_WRL  1950                                          2000000
# 1   World  OWID_WRL  1951                                          2000000
# 2   World  OWID_WRL  1952                                          2000000
# 3   World  OWID_WRL  1953                                          3000000
# 4   World  OWID_WRL  1954                                          3000000
# ..    ...       ...   ...                                              ...
# 64  World  OWID_WRL  2015                                        381000000
# 65  World  OWID_WRL  2016                                        400050000
# 66  World  OWID_WRL  2017                                        420052500
# 67  World  OWID_WRL  2018                                        441055140
# 68  World  OWID_WRL  2019                                        459746020
#
# [69 rows x 4 columns]]

# %%
correlation, p_value = pearsonr(df1['Year'], df1['Annua
                                                 l plastic production between 1950 and 2019'])

print(f"Pearson correlation coefficient: {correlation}")
print(f"P-value: {p_value}")
# Out:
#   Cell In [12], line 1
#     correlation, p_value = pearsonr(df1['Year'], df1['Annua
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Correlation coefficient
#x starts from 1950, 1 = 10yrs
#y: approximate numbers in milllions

x = [0,1,2,3,4,5,6,7]
y = [2, 8, 35, 70, 120, 213, 313, 460]



# Calculate r value
correlation_matrix = np.corrcoef(x, y)
rv1 = correlation_matrix[0, 1]
print(f"Entire Correlation coefficient (r)1950-2019: {rv1}")


x50_80 = [0,1,2,3]
y50_80 = [2,8,35,70]
correlation_matrix = np.corrcoef(x50_80, y50_80)
rv2 = correlation_matrix[0, 1]
print(f"Correlation coefficient (r)1950-1980: {rv2}")


x80_00 = [0,1,2]
y80_00 = [70, 120, 213]
correlation_matrix = np.corrcoef(x80_00, y80_00)
rv3 = correlation_matrix[0, 1]
print(f"Correlation coefficient (r)1980-2000: {rv3}")

x00_19 = [0,1,2]
y00_19 = [213,313,460]
correlation_matrix = np.corrcoef(x00_19, y00_19)
rv4 = correlation_matrix[0, 1]
print(f"Correlation coefficient (r)2000-2019: {rv4}")
# Out:
# Entire Correlation coefficient (r)1950-2019: 0.9427917039104364
# Correlation coefficient (r)1950-1980: 0.9613740491368894
# Correlation coefficient (r)1980-2000: 0.9852623097949474
# Correlation coefficient (r)2000-2019: 0.9940194526818468

# %%
#This code is generated by AI
initial_correlation, _ = pearsonr(x, y)

# Fit a polynomial of degree 2 (quadratic fit)
coefficients = np.polyfit(x, y, 2)
poly = np.poly1d(coefficients)

# Number of steps for prediction
num_predictions = 5  

# Extend the data for predictions
x_extended = x.copy()
y_extended = y.copy()

correlations = [initial_correlation]  

# Predict and calculate updated correlations
for i in range(num_predictions):
    next_x = x_extended[-1] + 10  # Increment years by 10 (or any other interval)
    predicted_y = poly(next_x)    # Predict the corresponding y value
    
    # Add the predicted point to the data
    x_extended = np.append(x_extended, next_x)
    y_extended = np.append(y_extended, predicted_y)
    
    # Calculate the updated correlation
    updated_correlation, _ = pearsonr(x_extended, y_extended)
    correlations.append(updated_correlation)
    

# Plotting the data and predictions
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x_extended, poly(x_extended), color='red', label='Polynomial Fit')
plt.scatter(x_extended[-num_predictions:], y_extended[-num_predictions:], color='green', label='Predicted Points')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Plastic Production (in hundred million kg)')
plt.title('Predicting Plastic Production until 2060')
plt.grid(True)
plt.show()

# Print correlations over iterations
print("Correlations at each step:")
for i, corr in enumerate(correlations):
    if i == 0:
        print(f"Initial Correlation: {corr:.4f}")
    else:
        print(f"After Prediction {i}: {corr:.4f}")

# %%
# Given data
x = [0, 1, 2, 3, 4, 5, 6, 7]
y = [2, 8, 35, 70, 120, 213, 313, 460]

# Loop through pairs of consecutive values and calculate r
for i in range(len(x) - 1):
    x_pair = x[i:i+2]
    y_pair = y[i:i+2]
    r_value, _ = pearsonr(x_pair, y_pair)
    print(f"correlation coefficient (r) for x{[x_pair[0], x_pair[1]]} and y{[y_pair[0], y_pair[1]]}: {r_value}")

# The correlation coefficient in each decade: r = 1
# Out:
# correlation coefficient (r) for x[0, 1] and y[2, 8]: 1.0
# correlation coefficient (r) for x[1, 2] and y[8, 35]: 1.0
# correlation coefficient (r) for x[2, 3] and y[35, 70]: 1.0
# correlation coefficient (r) for x[3, 4] and y[70, 120]: 1.0
# correlation coefficient (r) for x[4, 5] and y[120, 213]: 1.0
# correlation coefficient (r) for x[5, 6] and y[213, 313]: 1.0
# correlation coefficient (r) for x[6, 7] and y[313, 460]: 1.0

# %%
# Given data
x = np.array([1950, 1960, 1970, 1980, 1990, 2000, 2010, 2019])
y = np.array([2, 8, 35, 70, 120, 213, 313, 460])

# Fit a polynomial of degree 2 (quadratic fit)
coefficients = np.polyfit(x, y, 2)
poly = np.poly1d(coefficients)

# Number of steps for prediction
num_predictions = 5  # Predict next 5 values for x = 8, 9, 10, 11, 12

# Store predicted values and extended data
x_extended = x.copy()
y_extended = y.copy()

# Predict and update the correlation for each new value
for i in range(num_predictions):
    next_x = x_extended[-1] + 10  # The next x value
    predicted_y = poly(next_x)   # Predict the corresponding y value
    
    # Add the predicted point to the data
    x_extended = np.append(x_extended, next_x)
    y_extended = np.append(y_extended, predicted_y)
    
    # Calculate the updated correlation
    correlation_matrix = np.corrcoef(x_extended, y_extended)
    r_value = correlation_matrix[0, 1]
    

# Optional: Plotting the data and polynomial fit with extended predictions
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x_extended, poly(x_extended), color='red', label='Polynomial fit')
plt.scatter(x_extended[-num_predictions:], y_extended[-num_predictions:], color='green', label='Predicted Points')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Plastic production in hundread million kg')
plt.title('The prediction of the transition of plastic production until 2060')

plt.grid(False)

# %% [markdown]
# #⚠️[CAUTION!]⚠️
# #DATA 2 HAS AN UNCERTAINTY IN THE VARIABLE OF  'Share of global plastics emitted to ocean'
# #THE VALUE MIGHT BE THE PERCENTAGE BUT NO CLARIFICATION IS GAINED

# %%
df2 = pd.read_csv("2- share-of-global-plastic-waste-emitted-to-the-ocean.csv", index_col = 0)

# %%
df2.isnull()
# Out:
#                       Code   Year  Share of global plastics emitted to ocean
# Entity
# Africa                True  False                                      False
# Albania              False  False                                      False
# Algeria              False  False                                      False
# Angola               False  False                                      False
# Antigua and Barbuda  False  False                                      False
# ...                    ...    ...                                        ...
# Venezuela            False  False                                      False
# Vietnam              False  False                                      False
# Western Sahara       False  False                                      False
# Yemen                False  False                                      False
# Zimbabwe             False  False                                      False
#
# [170 rows x 3 columns]

# %%
p0 = df2[df2['Share of global plastics emitted to ocean'] == 0]
# A list of countries where NO plastic pollution to the ocean is below
p0
# Out:
#                  Code  Year  Share of global plastics emitted to ocean
# Entity
# Bahrain           BHR  2019                                        0.0
# Burkina Faso      BFA  2019                                        0.0
# Cape Verde        CPV  2019                                        0.0
# Comoros           COM  2019                                        0.0
# Finland           FIN  2019                                        0.0
# Iceland           ISL  2019                                        0.0
# Kiribati          KIR  2019                                        0.0
# Lesotho           LSO  2019                                        0.0
# Maldives          MDV  2019                                        0.0
# Malta             MLT  2019                                        0.0
# Marshall Islands  MHL  2019                                        0.0
# Mauritius         MUS  2019                                        0.0
# ...

# %%
nul_code = df2[df2['Code'].isnull()]
print(nul_code)
# Out:
#               Code  Year  Share of global plastics emitted to ocean
# Entity
# Africa         NaN  2019                                   7.989317
# Asia           NaN  2019                                  80.993570
# EU-27          NaN  2019                                   0.220224
# Europe         NaN  2019                                   0.595431
# Macau          NaN  2019                                   0.034815
# Micronesia     NaN  2019                                   0.003778
# North America  NaN  2019                                   4.499121
# Oceania        NaN  2019                                   0.370715
# Saint Martin   NaN  2019                                   0.000000
# Sint Maarten   NaN  2019                                   0.000000
# South America  NaN  2019                                   5.513253

# %%
df2_cleaned = df2.dropna()

# %%
# The number of plastic emittion in following zones are integrated respectively:
# Oceania(Oceania and Micronesia), Europe(Europe and EU-27), Asiaa(Asia and Macau)

data = {
    'Area':['Africa', 'Asia', 'Europe', 'South America', 'North America', 'Oceania'],
    'Plastic Emittion':[7.989317, 81.028385, 0.815655, 5.513253, 4.499121, 0.40553]
}

df2_zone = pd.DataFrame(data)
plt.figure(figsize=(10, 6))

plt.bar(df2_zone['Area'], df2_zone['Plastic Emittion'], color='orange')


plt.title('Share of global plastics emitted to ocean in 2019')
plt.xlabel('Area')
plt.ylabel('Plastic pollution to ocean')


plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# The number of plastic emission in the following zones are integrated respectively:
# Oceania (Oceania and Micronesia), Europe (Europe and EU-27), Asia (Asia and Macau)

data = {
    'Area': ['Africa', 'Asia', 'Europe', 'South America', 'North America', 'Oceania'],
    'Plastic Emittion': [7.989317, 81.028385, 0.815655, 5.513253, 4.499121, 0.40553]
}

df2_zone = pd.DataFrame(data)

plt.figure(figsize=(8, 8))

plt.pie(df2_zone['Plastic Emittion'], labels=df2_zone['Area'], autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightyellow', 'lightpink'])

plt.title('Share of Global Plastics Emitted to Ocean in 2019')

plt.tight_layout()

# %%
sum_area = df2_zone['Plastic Emittion'].sum()
sum_area
#This data is not out of 100% but nearly
# Out:
# 100.25126100000001

# %%
total_sum = df2['Share of global plastics emitted to ocean'].sum()
total_sum
# Out:
# 200.181631073

# %%
df3 = pd.read_csv("3- share-plastic-fate.csv")
'''
landfill etc
'''
# Out:
# '\nlandfill etc\n'

# %%
list[df3]
# Out:
# list[                   Entity      Code  Year  \
# 0    Americas (excl. USA)       NaN  2000
# 1    Americas (excl. USA)       NaN  2001
# 2    Americas (excl. USA)       NaN  2002
# 3    Americas (excl. USA)       NaN  2003
# 4    Americas (excl. USA)       NaN  2004
# ..                    ...       ...   ...
# 195                 World  OWID_WRL  2015
# 196                 World  OWID_WRL  2016
# 197                 World  OWID_WRL  2017
# 198                 World  OWID_WRL  2018
# 199                 World  OWID_WRL  2019
#
#      Share of waste recycled from total regional waste  \
# 0                                             4.721963
# 1                                             4.972505
# 2                                             5.227469
# 3                                             5.482511
# 4                                             5.740007
# ..                                                 ...
# 195                                           8.164696
# ...

# %%
df3.describe(include='all')
# Out:
#                       Entity Code         Year  \
# count                    200   80   200.000000
# unique                    10    4          NaN
# top     Americas (excl. USA)  CHN          NaN
# freq                      20   20          NaN
# mean                     NaN  NaN  2009.500000
# std                      NaN  NaN     5.780751
# min                      NaN  NaN  2000.000000
# 25%                      NaN  NaN  2004.750000
# 50%                      NaN  NaN  2009.500000
# 75%                      NaN  NaN  2014.250000
# max                      NaN  NaN  2019.000000
#
#         Share of waste recycled from total regional waste  \
# count                                          200.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             6.364439
# ...

# %%
column_names = df3.columns.tolist()

print(column_names)
# Out:
# ['Entity', 'Code', 'Year', 'Share of waste recycled from total regional waste', 'Share of waste incinerated from total regional waste', 'Share of littered and mismanaged from total regional waste', 'Share of waste landfilled from total regional waste']

# %%
df3.columns = df3.columns.str.strip()  # Remove extra spaces from column names
print(df3.columns)  # Check the updated column names
# Convert unique countries to a list
unique_countries_list = df3['Entity'].unique().tolist()

# Print the result
print(unique_countries_list)
# Strip spaces from column names
df3.columns = df3.columns.str.strip()

# Convert unique countries to a list
unique_countries_list = df3['Entity'].unique().tolist()

# Print the result
print(unique_countries_list)



'''
Ignore this row:
Error occured due to an unavailability to list the values in the column 'Entity'

'''
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Share of waste recycled from total regional waste',
#        'Share of waste incinerated from total regional waste',
#        'Share of littered and mismanaged from total regional waste',
#        'Share of waste landfilled from total regional waste'],
#       dtype='object')
# ['Americas (excl. USA)', 'Asia (excl. China and India)', 'China', 'Europe', 'India', 'Middle East & North Africa', 'Oceania', 'Sub-Saharan Africa', 'United States', 'World']
# ['Americas (excl. USA)', 'Asia (excl. China and India)', 'China', 'Europe', 'India', 'Middle East & North Africa', 'Oceania', 'Sub-Saharan Africa', 'United States', 'World']
# "\nIgnore this row:\nError occured due to an unavailability to list the values in the column 'Entity'\n\n"

# %%
df_2019 = df3[df3['Year'] == 2019]

print(df_2019)
# Out:
#                            Entity      Code  Year  \
# 19           Americas (excl. USA)       NaN  2019
# 39   Asia (excl. China and India)       NaN  2019
# 59                          China       CHN  2019
# 79                         Europe       NaN  2019
# 99                          India       IND  2019
# 119    Middle East & North Africa       NaN  2019
# 139                       Oceania       NaN  2019
# 159            Sub-Saharan Africa       NaN  2019
# 179                 United States       USA  2019
# 199                         World  OWID_WRL  2019
#
#      Share of waste recycled from total regional waste  \
# 19                                            9.554245
# 39                                            8.351267
# 59                                           12.801141
# 79                                           12.384406
# 99                                           13.333093
# 119                                           5.447833
# ...

# %%
df3_w19 = {
    'categories':['Share of waste recycled from total regional waste', 'Share of waste incinerated from total regional waste', 'Share of littered and mismanaged from total regional waste', 'Share of waste landfilled from total regional waste'],
    'percentage':[9.292344, 19.048033, 22.454480, 49.205143]
}
df3w19 = pd.DataFrame(df3_w19)


plt.figure(figsize=(8, 8))

plt.pie(df3w19['percentage'], labels=df3w19['categories'], autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightyellow', 'lightpink'])

plt.title('Global Plastic Distribution in 2019')

plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "World"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Global Waste Categories (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
df3['Year'] = df3['Year'].astype(str)

df3_w = df3[df3['Entity'] == "Americas (excl. USA)"]

plt.figure(figsize=(10, 6))

plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')


plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories Americas (excl. USA) (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

plt.tight_layout()

# %%
df3['Year'] = df3['Year'].astype(str)


df3_w = df3[df3['Entity'] == "Asia (excl. China and India)"]

plt.figure(figsize=(10, 6))

plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in Asia (excl. China and India) (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
df3['Year'] = df3['Year'].astype(str)

df3_w = df3[df3['Entity'] == "China"]

plt.figure(figsize=(10, 6))


plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')


plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in China from 2000 - 2019')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)


plt.tight_layout()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "Europe"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in Europe (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "India"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in India (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "Middle East & North Africa"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in Middle East & North Africa (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "Oceania"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in Oceania (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "Sub-Saharan Africa"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in Sub-Saharan Africa (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Converting the value of 'Year' into string data type
df3['Year'] = df3['Year'].astype(str)

#Choosing the area
df3_w = df3[df3['Entity'] == "United States"]

# Plotting
plt.figure(figsize=(10, 6))

# Plot each category
plt.plot(df3_w['Year'], df3_w['Share of waste recycled from total regional waste'], label='Recycled', marker='o')
plt.plot(df3_w['Year'], df3_w['Share of waste incinerated from total regional waste'], label='Incinerated', marker='s')
plt.plot(df3_w['Year'], df3_w['Share of littered and mismanaged from total regional waste'], label='Littered & Mismanaged', marker='^')
plt.plot(df3_w['Year'], df3_w['Share of waste landfilled from total regional waste'], label='Landfilled', marker='x')

# Labels and Title
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Transition of Waste Categories in United States (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(False)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
'''
'''
df3_w19 = {
    'categories':['Share of waste recycled from total regional waste', 'Share of waste incinerated from total regional waste', 'Share of littered and mismanaged from total regional waste', 'Share of waste landfilled from total regional waste'],
    'percentage':[9.292344, 19.048033, 22.454480, 49.205143]
}
df3w19 = pd.DataFrame(df3_w19)


plt.figure(figsize=(8, 8))

plt.pie(df3w19['percentage'], labels=df3w19['categories'], autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightyellow', 'lightpink'])

plt.title('Global Plastic Distribution in 2019')

plt.tight_layout()
plt.show()
''''''
# Out:
# ''

# %%
df4 = pd.read_csv("4- mismanaged-plastic-waste-per-capita.csv")

df4
# Out:
#                   Entity      Code  Year  \
# 0                 Africa       NaN  2019
# 1                Albania       ALB  2019
# 2                Algeria       DZA  2019
# 3                 Angola       AGO  2019
# 4    Antigua and Barbuda       ATG  2019
# ..                   ...       ...   ...
# 160              Vietnam       VNM  2019
# 161       Western Sahara       ESH  2019
# 162                World  OWID_WRL  2019
# 163                Yemen       YEM  2019
# 164             Zimbabwe       ZWE  2019
#
#      Mismanaged plastic waste per capita (kg per year)
# 0                                            10.465928
# 1                                            24.239153
# 2                                            17.758995
# 3                                             7.445279
# 4                                             6.463918
# ..                                                 ...
# 160                                          11.536045
# ...

# %%
country = df4["Entity"].tolist()

# %%
country
# Out:
# ['Africa',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Asia',
#  'Australia',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cyprus',
#  'Democratic Republic of Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'East Timor',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Europe',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Guiana',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guadeloupe',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
# ...

# %%
code = df4["Code"].tolist()
code
# Out:
# [nan,
#  'ALB',
#  'DZA',
#  'AGO',
#  'ATG',
#  'ARG',
#  nan,
#  'AUS',
#  'BHS',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BEL',
#  'BLZ',
#  'BEN',
#  'BIH',
#  'BRA',
#  'BRN',
#  'BGR',
#  'BFA',
#  'KHM',
#  'CMR',
#  'CAN',
#  'CPV',
#  'CHL',
#  'CHN',
#  'COL',
#  'COM',
#  'COG',
#  'CRI',
#  'CIV',
#  'HRV',
#  'CYP',
#  'COD',
#  'DNK',
#  'DJI',
#  'DMA',
#  'DOM',
#  'TLS',
#  'ECU',
#  'EGY',
#  'SLV',
#  'GNQ',
#  'ERI',
#  'EST',
#  nan,
#  'FJI',
#  'FIN',
#  'FRA',
#  'GUF',
#  'GAB',
#  'GMB',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GRC',
#  'GRD',
#  'GLP',
#  'GTM',
#  'GIN',
#  'GNB',
#  'GUY',
#  'HTI',
#  'HND',
#  'HKG',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRN',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JPN',
#  'JOR',
#  'KAZ',
#  'KEN',
#  'KIR',
#  'KWT',
#  'LVA',
#  'LBN',
#  'LSO',
#  'LBR',
#  'LBY',
#  'LTU',
#  'MDG',
#  'MYS',
#  'MDV',
#  'MLT',
#  'MHL',
#  'MTQ',
#  'MRT',
#  'MUS',
#  'MEX',
#  'MCO',
#  'MNE',
#  'MAR',
#  'MOZ',
#  'MMR',
# ...

# %%
null_rows = df4[df4.isnull().any(axis=1)]

# Display the rows containing null values
print("\nRows containing null values:")
print(null_rows)
# Out:
# Rows containing null values:
#             Entity Code  Year  \
# 0           Africa  NaN  2019
# 6             Asia  NaN  2019
# 45          Europe  NaN  2019
# 105  North America  NaN  2019
# 108        Oceania  NaN  2019
#
#      Mismanaged plastic waste per capita (kg per year)
# 0                                            10.465928
# 6                                             8.667235
# 45                                            1.580226
# 105                                           5.257716
# 108                                           3.240268

# %%
#Missing data of South Amrica
south_american_countries = ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 
                            'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela']
data = {
    'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 
                'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'],
    'Value': [10.4, 15.6, 1.62, 1.7, 6.26, 35.2, 5.62, 4.31, 39.47, 26.75, 23.54]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#       Country  Value
# 0   Argentina  10.40
# 1      Brazil  15.60
# 2       Chile   1.62
# 3    Colombia   1.70
# 4     Ecuador   6.26
# 5      Guyana  35.20
# 6    Paraguay   5.62
# 7        Peru   4.31
# 8    Suriname  39.47
# 9     Uruguay  26.75
# 10  Venezuela  23.54

# %%
#Median of South America is 10.4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data
data = {
    'Area': ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania'],
    'Value': [10.465928, 8.667235, 1.580226, 5.257716, 10.4, 3.240268],
    'Year': [2019] * 6  # Year is constant at 2019 for all entries
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the figure size for better clarity
plt.figure(figsize=(10, 6))

# Create the bar chart
plt.bar(df['Area'], df['Value'], color='skyblue')

# Add title and labels
plt.title('Individual plastic waste for the Year 2019')
plt.xlabel('Area')
plt.ylabel('Mismanaged plastic waste per capita (kg per year)')

# Show the plot
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
'''

To calculate the median mismanaged plastic waste per capita for each region (e.g., North America, Asia, Africa, etc.), I will compute the values based on the provided data. Let's proceed with this calculation.

Here are the median values of mismanaged plastic waste per capita (kg per year) for each region:

Africa: 10.885 kg
Asia: 9.085 kg
Australia: 0.210 kg
Europe: 2.475 kg
North America: 6.905 kg
Oceania: 5.160 kg ​​

'''
# Out:
# "\n\nTo calculate the median mismanaged plastic waste per capita for each region (e.g., North America, Asia, Africa, etc.), I will compute the values based on the provided data. Let's proceed with this calculation.\n\nHere are the median values of mismanaged plastic waste per capita (kg per year) for each region:\n\nAfrica: 10.885 kg\nAsia: 9.085 kg\nAustralia: 0.210 kg\nEurope: 2.475 kg\nNorth America: 6.905 kg\nOceania: 5.160 kg \u200b\u200b\n\n"

# %%
df4_cleaned = df4.dropna()

# %%
print(max(df4_cleaned['Mismanaged plastic waste per capita (kg per year)']))
# Out:
# 69.51586369

# %%
df4_cleaned.sort_values(
    by='Mismanaged plastic waste per capita (kg per year)', 
    ascending=False
).head()
# Out:
#                   Entity Code  Year  \
# 27               Comoros  COM  2019
# 151  Trinidad and Tobago  TTO  2019
# 143             Suriname  SUR  2019
# 116          Philippines  PHL  2019
# 164             Zimbabwe  ZWE  2019
#
#      Mismanaged plastic waste per capita (kg per year)
# 27                                           69.515864
# 151                                          52.429391
# 143                                          39.471601
# 116                                          37.230963
# 164                                          35.839194

# %%
df4_cleaned.sort_values(
    by='Mismanaged plastic waste per capita (kg per year)', 
    ascending=True
).head(10)
# Out:
#           Entity Code  Year  Mismanaged plastic waste per capita (kg per year)
# 137      Somalia  SOM  2019                                           0.002720
# 106  North Korea  PRK  2019                                           0.012546
# 96    Montenegro  MNE  2019                                           0.025478
# 145        Syria  SYR  2019                                           0.029408
# 34       Denmark  DNK  2019                                           0.067568
# 52       Georgia  GEO  2019                                           0.076808
# 88      Maldives  MDV  2019                                           0.112994
# 95        Monaco  MCO  2019                                           0.128205
# 12       Belgium  BEL  2019                                           0.197937
# 7      Australia  AUS  2019                                           0.208943

# %%
# Complete dataset of plastic waste per capita in  2023
data = {
    "Country": [
        "Africa", "Albania", "Algeria", "Angola", "Antigua and Barbuda", "Argentina", 
        "Asia", "Australia", "Bahamas", "Bahrain", "Bangladesh", "Barbados", "Belgium", 
        "Belize", "Benin", "Bosnia and Herzegovina", "Brazil", "Brunei", "Bulgaria", 
        "Burkina Faso", "Cambodia", "Cameroon", "Canada", "Cape Verde", "Chile", "China", 
        "Colombia", "Comoros", "Congo", "Costa Rica", "Cote d'Ivoire", "Croatia", "Cyprus", 
        "Democratic Republic of Congo", "Denmark", "Djibouti", "Dominica", 
        "Dominican Republic", "East Timor", "Ecuador", "Egypt", "El Salvador", 
        "Equatorial Guinea", "Eritrea", "Estonia", "Europe", "Fiji", "Finland", "France", 
        "French Guiana", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", 
        "Grenada", "Guadeloupe", "Guatemala", "Guinea", "Guinea-Bissau", "Guyana", "Haiti", 
        "Honduras", "Hong Kong", "Iceland", "India", "Indonesia", "Iran", "Iraq", "Ireland", 
        "Israel", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Kiribati", 
        "Kuwait", "Latvia", "Lebanon", "Lesotho", "Liberia", "Libya", "Lithuania", 
        "Madagascar", "Malaysia", "Maldives", "Malta", "Marshall Islands", "Martinique", 
        "Mauritania", "Mauritius", "Mexico", "Monaco", "Montenegro", "Morocco", 
        "Mozambique", "Myanmar", "Namibia", "Netherlands", "New Zealand", "Nicaragua", 
        "Nigeria", "North America", "North Korea", "Norway", "Oceania", "Oman", "Pakistan", 
        "Palau", "Palestine", "Panama", "Papua New Guinea", "Peru", "Philippines", "Poland", 
        "Portugal", "Puerto Rico", "Qatar", "Reunion", "Romania", "Russia", "Saint Kitts and Nevis", 
        "Saint Lucia", "Saint Vincent and the Grenadines", "Samoa", "Sao Tome and Principe", 
        "Saudi Arabia", "Senegal", "Seychelles", "Sierra Leone", "Singapore", "Slovakia", 
        "Slovenia", "Solomon Islands", "Somalia", "South Africa", "South Korea", "Spain", 
        "Sri Lanka", "Sudan", "Suriname", "Sweden", "Syria", "Taiwan", "Tanzania", "Thailand", 
        "Togo", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", 
        "United Arab Emirates", "United Kingdom", "United States", "Uruguay", "Venezuela", 
        "Vietnam", "Western Sahara", "World", "Yemen", "Zimbabwe"
    ],
    "MismanagedPlasticWastePerCapita": [
        10.46592827, 24.23915307, 17.75899473, 7.445278869, 6.463917526, 10.40191152, 
        8.667235444, 0.20894338, 5.686375321, 0.635588056, 6.268108387, 3.038327526, 
        0.19793743, 15.43846154, 11.29861876, 16.82853681, 15.62046908, 1.598152425, 
        0.445285714, 15.61429064, 15.01152423, 22.36814036, 0.630483013, 6.487272727, 
        1.623417054, 8.559308412, 1.697570472, 69.51586369, 12.13361829, 1.139263074, 
        11.33934751, 4.247941889, 0.698081735, 15.78193592, 0.067567568, 10.56365503, 
        15.02777778, 18.06667287, 13.33642691, 6.262058248, 14.29961748, 3.361171367, 
        6.934365782, 24.0457535, 0.452488688, 1.580226046, 4.334831461, 0.473788865, 
        0.426531552, 0.432989691, 2.757017948, 14.9467632, 0.076807606, 0.606774669, 
        17.09520679, 0.430249212, 12.11607143, 0.405, 17.68972186, 11.58852087, 
        10.65330557, 35.20434227, 21.12829619, 14.97999179, 0.777434104, 0.445427729, 
        9.509608, 3.045657286, 5.981679813, 12.51007377, 0.547931176, 0.711351098, 
        0.640842279, 16.84972863, 0.281286458, 12.31686795, 2.92393941, 5.514455815, 
        0.627118644, 0.627525553, 0.500786576, 6.800175029, 14.30164706, 8.087907636, 
        27.81983178, 0.375724638, 0.936260151, 25.491518, 0.11299435, 0.588636364, 
        0.271186441, 0.369680851, 4.594785683, 0.235433071, 3.375352731, 0.128205128, 
        0.025477707, 8.101776705, 14.30652704, 8.038338422, 8.373547094, 0.890975025, 
        0.358352498, 16.93583868, 9.698005613, 5.257716269, 0.01254578, 0.277746793, 
        3.240267755, 0.251457286, 6.21734837, 6.444444444, 0.427424212, 8.558407913, 
        13.62101185, 4.315995078, 37.23096275, 0.372782939, 0.373362018, 0.440845551, 
        0.540960452, 0.262092238, 2.693570875, 2.491149775, 1.830188679, 23.36612022, 
        11.12612613, 8.822335025, 9.623255814, 0.209402084, 4.029209622, 0.336734694, 
        11.67784462, 0.425223983, 0.315008246, 0.405964406, 5.253731343, 0.002719679, 
        12.09855186, 0.237306003, 0.435415196, 7.290658413, 18.25672109, 39.47160069, 
        0.423973695, 0.029408319, 0.315554808, 29.59055254, 19.55720564, 15.06842366, 
        6.403846154, 52.42939068, 24.7574177, 19.85029366, 8.950697822, 0.525534746, 
        0.442973493, 0.812815117, 26.75332178, 23.54576378, 11.53604528, 7.068728522, 
        8.008550858, 10.00401207, 35.83919426
    ]
}

# %%
df5 = pd.read_csv("Plastic Waste Around the World.csv",index_col = 0)

# %%
df5.describe()
# Out:
#        Total_Plastic_Waste_MT  Recycling_Rate  Per_Capita_Waste_KG
# count              165.000000      165.000000           165.000000
# mean                 1.723515       13.096364           122.255152
# std                  6.001944       16.687354           222.849695
# min                  0.010000        0.100000             2.600000
# 25%                  0.120000        1.200000            17.300000
# 50%                  0.510000        5.400000            54.900000
# 75%                  1.330000       16.400000           127.500000
# max                 59.080000       84.800000          1564.400000

# %%
list[df5]
# Out:
# list[                  Total_Plastic_Waste_MT           Main_Sources  \
# Country
# China                              59.08   Packaging_Industrial
# United States                      42.02     Packaging_Consumer
# India                              26.33         Consumer_Goods
# Japan                               7.99  Packaging_Electronics
# Germany                             6.28   Automotive_Packaging
# ...                                  ...                    ...
# Marshall Islands                    0.01     Consumer_Packaging
# Micronesia                          0.01     Consumer_Packaging
# Palau                               0.01     Consumer_Packaging
# Tuvalu                              0.01     Consumer_Packaging
# Nauru                               0.01     Consumer_Packaging
#
#                   Recycling_Rate  Per_Capita_Waste_KG Coastal_Waste_Risk
# Country
# China                       29.8                 41.2               High
# ...

# %%
df5.sort_values(
    by='Total_Plastic_Waste_MT', 
    ascending=False
).head(10)
# Out:
#                 Total_Plastic_Waste_MT           Main_Sources  Recycling_Rate  \
# Country
# China                            59.08   Packaging_Industrial            29.8
# United States                    42.02     Packaging_Consumer            32.1
# India                            26.33         Consumer_Goods            11.5
# Japan                             7.99  Packaging_Electronics            84.8
# Germany                           6.28   Automotive_Packaging            56.1
# Brazil                            5.96     Consumer_Packaging             1.2
# Indonesia                         5.85         Food_Packaging            11.8
# Russia                            5.84    Industrial_Consumer             5.6
# United Kingdom                    5.03     Packaging_Consumer            46.2
# France                            4.98     Packaging_Consumer            27.3
#
#                 Per_Capita_Waste_KG Coastal_Waste_Risk
# Country
# ...

# %%
df5.sort_values(
    by='Per_Capita_Waste_KG', 
    ascending=False
).head(10)
# Out:
#                      Total_Plastic_Waste_MT          Main_Sources  \
# Country
# Iceland                                0.57    Consumer_Packaging
# Malta                                  0.59    Consumer_Packaging
# Montenegro                             0.63    Consumer_Packaging
# Luxembourg                             0.61  Industrial_Packaging
# Nauru                                  0.01    Consumer_Packaging
# Tuvalu                                 0.01    Consumer_Packaging
# Estonia                                0.71  Industrial_Packaging
# Cyprus                                 0.65    Consumer_Packaging
# Trinidad and Tobago                    0.67    Consumer_Packaging
# Palau                                  0.01    Consumer_Packaging
#
#                      Recycling_Rate  Per_Capita_Waste_KG Coastal_Waste_Risk
# Country
# Iceland                        55.6               1564.4                Low
# ...

# %%
df5.sort_values(
    by='Coastal_Waste_Risk', 
    ascending=False
).head(10)
# Out:
#                Total_Plastic_Waste_MT        Main_Sources  Recycling_Rate  \
# Country
# Philippines                      1.63      Food_Packaging             9.1
# Maldives                         0.04  Consumer_Packaging             3.2
# Indonesia                        5.85      Food_Packaging            11.8
# Vietnam                          2.54      Food_Packaging            15.3
# Portugal                         1.39  Consumer_Packaging            31.2
# Laos                             0.49  Consumer_Packaging             1.8
# United States                   42.02  Packaging_Consumer            32.1
# South Africa                     1.58  Consumer_Packaging            18.9
# Colombia                         1.54  Consumer_Packaging             7.8
# Malta                            0.59  Consumer_Packaging            11.2
#
#                Per_Capita_Waste_KG Coastal_Waste_Risk
# Country
# Philippines                   14.8          Very_High
# ...

# %%
df5.sort_values(
    by='Recycling_Rate', 
    ascending=False
).head(20)
# Out:
#                 Total_Plastic_Waste_MT           Main_Sources  Recycling_Rate  \
# Country
# Japan                             7.99  Packaging_Electronics            84.8
# Singapore                         1.27   Industrial_Packaging            59.8
# South Korea                       2.91  Electronics_Packaging            59.1
# Austria                           1.48   Industrial_Packaging            56.4
# Germany                           6.28   Automotive_Packaging            56.1
# Netherlands                       1.78   Industrial_Packaging            55.9
# Iceland                           0.57     Consumer_Packaging            55.6
# Sweden                            1.51   Packaging_Industrial            50.6
# Luxembourg                        0.61   Industrial_Packaging            48.9
# United Kingdom                    5.03     Packaging_Consumer            46.2
# Lithuania                         0.93   Industrial_Packaging            45.3
# ...

# %%
df5.sort_values(
    by='Recycling_Rate', 
    ascending=True
).head(50)
# Out:
#                               Total_Plastic_Waste_MT        Main_Sources  \
# Country
# Chad                                            0.09  Consumer_Packaging
# Somalia                                         0.33  Consumer_Packaging
# Central African Republic                        0.04  Consumer_Packaging
# Liberia                                         0.05  Consumer_Packaging
# Niger                                           0.11  Consumer_Packaging
# Western Sahara                                  0.01  Consumer_Packaging
# Mali                                            0.12  Consumer_Packaging
# Eritrea                                         0.05  Consumer_Packaging
# Guinea-Bissau                                   0.04  Consumer_Packaging
# Yemen                                           0.43  Consumer_Packaging
# Sierra Leone                                    0.06  Consumer_Packaging
# Burkina Faso                                    0.14  Consumer_Packaging
# ...

# %%
# recycling Top 20
data = {
    "Country": ["Japan", "Singapore", "South Korea", "Austria", "Germany", "Netherlands", "Iceland", 
                "Sweden", "Luxembourg", "United Kingdom", "Lithuania", "Norway", "Belgium", 
                "Latvia", "Denmark", "Slovenia", "Finland", "Czech Republic", "Italy", "Slovakia"],
    "Recycling_Rate": [84.8, 59.8, 59.1, 56.4, 56.1, 55.9, 55.6, 50.6, 48.9, 46.2, 45.3, 44.5, 
                       43.2, 43.2, 42.3, 42.1, 42.1, 41.7, 41.2, 38.9]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Sorting the data by Recycling Rate in descending order
df_sorted = df.sort_values(by="Recycling_Rate", ascending=False)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_sorted["Country"], df_sorted["Recycling_Rate"], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Recycling Rate (%)')
plt.title('Top Recycling Rates by Country')
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()

# %%
data = {
    "Country": ["China", "United States", "India", "Japan", "Germany", "Brazil", "Indonesia", "Russia", "United Kingdom", "France"],
    "Total_Plastic_Waste_MT": [59.08, 42.02, 26.33, 7.99, 6.28, 5.96, 5.85, 5.84, 5.03, 4.98],
    "Main_Sources": ["Consumer Packaging", "Packaging Consumer", "Consumer Goods", "Packaging Electronics", "Automotive Packaging",
                     "Consumer Packaging", "Food Packaging", "Industrial Consumer", "Packaging Consumer", "Packaging Consumer"],
    "Recycling_Rate": [29.8, 32.1, 11.5, 84.8, 56.1, 1.2, 11.8, 5.6, 46.2, 27.3],
    "Per_Capita_Waste_KG": [41.2, 127.5, 19.3, 63.2, 75.6, 28.1, 21.3, 40.2, 74.3, 73.1],
    "Coastal_Waste_Risk": ["High", "Medium", "High", "Medium", "Low", "Medium", "Very High", "Medium", "Low", "Low"]
}

df = pd.DataFrame(data)

# Display the dataset
print("Dataset Preview:")
print(df.head())

# Visualization setup
sns.set(style="whitegrid")

# 1. Bar chart for total plastic waste production
plt.figure(figsize=(10, 6))
sns.barplot(x="Total_Plastic_Waste_MT", y="Country", data=df, palette="Blues_d")
plt.title("Country-wise Plastic Waste Production (Million Metric Tons)")
plt.xlabel("Total Plastic Waste (MT)")
plt.ylabel("Country")
plt.show()

# 2. Recycling rate by country
plt.figure(figsize=(10, 6))
sns.barplot(x="Recycling_Rate", y="Country", data=df, palette="Greens_d")
plt.title("Recycling Rates by Country (%)")
plt.xlabel("Recycling Rate (%)")
plt.ylabel("Country")
plt.show()

# 3. Coastal waste risk by country
plt.figure(figsize=(10, 6))
sns.countplot(y="Coastal_Waste_Risk", data=df, palette="coolwarm", order=df['Coastal_Waste_Risk'].value_counts().index)
plt.title("Coastal Waste Risk Levels")
plt.xlabel("Count")
plt.ylabel("Coastal Waste Risk")
plt.show()

# 4. Scatter plot: Per capita waste vs Recycling rate
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Per_Capita_Waste_KG", y="Recycling_Rate", hue="Coastal_Waste_Risk", data=df, palette="Set2", s=100)
plt.title("Per Capita Waste Production vs Recycling Rate")
plt.xlabel("Per Capita Waste (KG/person)")
plt.ylabel("Recycling Rate (%)")
plt.legend(title="Coastal Waste Risk")
plt.show()

# 5. Pie chart: Main sources of plastic waste
sources = df["Main_Sources"].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(sources, labels=sources.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Main Sources of Plastic Waste")
plt.show()

# Additional analysis
print("\nSummary Statistics:")
print(df.describe())

print("\nCoastal Waste Risk Distribution:")
print(df["Coastal_Waste_Risk"].value_counts())

# %%
#PER CAPITA IN 2023 categorised by region
data23 = {
    'Country': ['China', 'India', 'United States', 'Nigeria', 'South Africa', 'Brazil', 'Germany', 'Japan'],
    'Region': ['Asia', 'Asia', 'North America', 'Africa', 'Africa', 'South America', 'Europe', 'Asia'],
    'Per Capita Waste (kg/person)': [32.1, 11.5, 127.5, 7.3, 26.4, 28.1, 75.6, 63.2]
}

# Convert to DataFrame
df = pd.DataFrame(data23)

# Sum the 'Per Capita Waste (kg/person)' by region
region_waste = df.groupby('Region')['Per Capita Waste (kg/person)'].sum()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
region_waste.plot(kind='bar', color='skyblue')
plt.title('Total Per Capita Waste by Region')
plt.xlabel('Region')
plt.ylabel('Total Per Capita Waste (kg/person)')
plt.xticks(rotation=45)
plt.show()

# %%
# Whole data in column of per capita waste production (kg/person)
'''
data23 = {
    'Country': [
        'China', 'United States', 'India', 'Japan', 'Germany', 'Brazil', 'Indonesia', 'Russia', 
        'United Kingdom', 'France', 'Mexico', 'Canada', 'Italy', 'Turkey', 'South Korea', 
        'Spain', 'Vietnam', 'Thailand', 'Malaysia', 'Poland', 'Egypt', 'Argentina', 'Netherlands', 
        'Australia', 'Saudi Arabia', 'Philippines', 'Bangladesh', 'Pakistan', 'South Africa', 'Colombia',
        'Nigeria', 'Belgium', 'Sweden', 'Austria', 'Ukraine', 'Greece', 'Czech Republic', 'Romania', 
        'Portugal', 'Hungary', 'Denmark', 'Finland', 'Norway', 'Ireland', 'Singapore', 'Chile', 'Israel', 
        'Peru', 'Kazakhstan', 'Morocco', 'Algeria', 'Slovakia', 'Ecuador', 'Belarus', 'Dominican Republic',
        'Bulgaria', 'Tunisia', 'Sri Lanka', 'Azerbaijan', 'Croatia', 'Uruguay', 'Lithuania', 'Slovenia', 
        'Costa Rica', 'Panama', 'Kuwait', 'Jordan', 'Lebanon', 'Oman', 'Bolivia', 'Paraguay', 'Latvia', 
        'Estonia', 'Bahrain', 'Trinidad and Tobago', 'Cyprus', 'Montenegro', 'Luxembourg', 'Malta', 'Iceland', 
        'Qatar', 'Cambodia', 'Myanmar', 'Laos', 'Mongolia', 'Afghanistan', 'Yemen', 'Syria', 'Iraq', 'Libya', 
        'Sudan', 'Somalia', 'Ethiopia', 'Kenya', 'Tanzania', 'Uganda', 'Rwanda', 'Burundi', 'Malawi', 'Mozambique',
        'Zimbabwe', 'Zambia', 'Angola', 'Namibia', 'Botswana', 'Lesotho', 'Eswatini', 'Madagascar', 'Comoros', 
        'Mauritius', 'Seychelles', 'Cape Verde', 'Sao Tome and Principe', 'Guinea-Bissau', 'Guinea', 'Sierra Leone',
        'Liberia', 'Ivory Coast', 'Ghana', 'Togo', 'Benin', 'Mali', 'Burkina Faso', 'Niger', 'Chad', 
        'Central African Republic', 'Cameroon', 'Gabon', 'Republic of Congo', 'Democratic Republic of Congo',
        'Eritrea', 'Djibouti', 'Senegal', 'Gambia', 'Mauritania', 'Western Sahara', 'Moldova', 'Albania', 'North Macedonia',
        'Bosnia and Herzegovina', 'Kosovo', 'Georgia', 'Armenia', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan', 'Uzbekistan',
        'Nepal', 'Bhutan', 'Maldives', 'Brunei', 'East Timor', 'Papua New Guinea', 'Solomon Islands', 'Vanuatu', 
        'New Caledonia', 'Fiji', 'Samoa', 'Tonga', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Palau', 'Tuvalu', 
        'Nauru'
    ],
    'Per_Capita_Waste_KG': [
        32.1, 127.5, 11.5, 84.8, 63.2, 28.1, 21.3, 40.2, 46.2, 73.1, 34.2, 102.1, 41.2, 38.5, 56.7, 54.9, 25.8, 34.5, 70.2,
        58.3, 19.3, 43.5, 102.8, 64.8, 46.9, 14.8, 9.7, 7.1, 26.4, 30.1, 131.2, 146.3, 164.8, 33.7, 133.9, 135.8, 141.5, 232.1,
        240.2, 243.1, 257.3, 217.9, 64.7, 133.7, 36.4, 62.8, 25.9, 207.1, 61.8, 115.7, 97.6, 152.3, 85.9, 46.7, 96.8, 238.1, 
        272.4, 386.8, 534.6, 397.7, 478.6, 531.1, 1004.8, 957.8, 1331.5, 1564.4, 188.7, 44.7, 16.5, 42.9, 138.6, 76.9, 92.7, 
        82.4, 168.5, 86.3, 437.2, 833.3, 927.8
    ]
}
'''

# %%
# Plasti Wate per capita in 2023: value represents median by following the categoriesbelow:
'''

Africa = {
    'Country': ['Angola', 'Algeria', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Cape Verde', 'Chad', 
                'Comoros', 'Congo', 'Democratic Republic of Congo', 'Djibouti', 'Egypt', 'Eritrea', 'Ethiopia', 
                'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 
                'Libya', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 
                'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somalia', 'South Africa', 'Sudan', 'Tanzania', 'Togo', 
                'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
    'Region': ['Africa'] * 43,  # All countries listed are in Africa
    'Per Capita Waste (kg/person)': [1.25, 1.45, 1.23, 1.56, 1.02, 0.87, 1.10, 1.23, 0.98, 1.05, 0.92, 0.78, 1.50, 
                                     1.75, 0.96, 1.10, 1.02, 1.50, 1.30, 1.25, 1.15, 1.12, 1.45, 1.32, 0.95, 1.03, 
                                     1.40, 1.02, 1.24, 1.23, 1.20, 1.12, 1.10, 1.25, 1.23, 1.32, 1.30, 1.23, 1.15, 
                                     1.10, 1.08, 1.20, 1.19]
}
Europe = {

    'Country': ['Germany', 
                'Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 
                'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 
                'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Liechtenstein', 
                'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 
                'Norway', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 
                'Ukraine', 'United Kingdom'],
    'Region': ['Europe', 'Oceania', 'Asia', 
               'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 
               'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 
               'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 
               'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 
               'Europe', 'Europe'],
    'Per Capita Waste (kg/person)': [ 6.28, 3.12, 2.45, 6.0, 5.75, 
                                     5.23, 5.67, 4.99, 5.54, 3.85, 6.03, 4.95, 6.7, 5.68, 4.77, 7.02, 6.1, 
                                     5.3, 6.6, 5.45, 4.75, 6.0, 4.88, 5.9, 4.25, 6.5, 7.0, 4.1, 4.8, 
                                     5.2, 5.3, 4.5, 5.6, 5.75, 4.9, 4.55, 6.4, 4.65, 5.6]
}

North America = {
    'Country': ['Canada', 'Costa Rica', 'Dominican Republic', 'El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Panama', 'United States'],
    'Per Capita Waste (kg/person)': [127.5, 5.96, 1.53, 1.67, 26.33, 7.99, 59.08, 1.67, 127.5]
}

South America = 


Asia = {
    'Country': ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Bahrain', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 
                'Georgia', 'India', 'Indonesia', 'Iran', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 
                'Lebanon', 'Malaysia', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestine', 'Philippines', 
                'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Taiwan', 'Tajikistan', 'Thailand', 
                'Timor-Leste', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'],
    'Per Capita Waste (kg/person)': [59.08, 26.33, 27.62, 1.39, 41.45, 1.03, 21.02, 3.62, 59.08, 6.73, 
                                     16.43, 26.33, 5.58, 6.61, 31.18, 127.5, 6.28, 11.13, 24.62, 5.28, 7.56, 
                                     1.56, 6.52, 2.83, 3.22, 4.78, 7.59, 5.52, 1.67, 7.18, 0.59, 
                                     9.05, 7.29, 8.12, 4.02, 5.72, 2.63, 8.02, 4.52, 5.03, 5.12, 3.98, 0.97]
}

Oceana= {
    'Country': ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 
                'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa', 'Solomon Islands', 
                'Tonga', 'Tuvalu', 'Vanuatu'],
    'Region': ['Oceania']*14,  # All countries belong to Oceania
    'Per Capita Waste (kg/person)': [1.67, 1.25, 0.45, 0.6, 0.9, 0.5, 1.5, 0.8, 0.6, 
                                     0.4, 0.35, 0.75, 0.55, 0.3]  # Example waste data
}
'''
continents = ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania']
values = [1.2, 6.52, 5.45, 7.99, 3.5, 0.6]


plt.figure(figsize=(10, 6))
plt.bar(continents, values, color='skyblue')

plt.xlabel('Region')
plt.ylabel('Plastic waste(kg/person)')
plt.title('Plastic wate per capita(median) in 2023')
plt.show()

# %%
#Compareing the median value of plastic waste per person in 2019 and 2023
import pandas as pd
import matplotlib.pyplot as plt

# Dataset 1 (data23)
data23 = {
    'continents': ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania'],
    'values': [1.2, 6.52, 5.45, 7.99, 3.5, 0.6]
}

# Dataset 2 (data19)
data19 = {
    'Area': ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania'],
    'Value': [10.465928, 8.667235, 1.580226, 5.257716, 10.4, 3.240268]
}

# Convert data23 and data19 to pandas DataFrames
df1 = pd.DataFrame(data23)
df2 = pd.DataFrame(data19)

# Merge the two datasets on the common column (continents / Area)
merged_df = pd.merge(df1, df2, left_on='continents', right_on='Area', how='inner')

# Calculate the difference between the two values
merged_df['Value Difference'] = merged_df['Value'] - merged_df['values']

# Create a bar chart to visualize the comparison
plt.figure(figsize=(10, 6))

# Set up the bar chart for the two datasets
bar_width = 0.35
index = range(len(merged_df))

# Plot the bars (data19 on the left, data23 on the right)
plt.bar(index, merged_df['Value'], bar_width, label='2019', color='orange')
plt.bar([i + bar_width for i in index], merged_df['values'], bar_width, label='2023', color='skyblue')

# Add labels and title
plt.xlabel('Continents')
plt.ylabel('Values')
plt.title('Comparison of Two Datasets about the individual plastic waste(kg) by Continent in 2019 and 2023')
plt.xticks([i + bar_width / 2 for i in index], merged_df['continents'])
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Print the merged DataFrame to see the comparison
print(merged_df[['continents', 'Value', 'values', 'Value Difference']])
# Out:
#       continents      Value  values  Value Difference
# 0         Africa  10.465928    1.20          9.265928
# 1           Asia   8.667235    6.52          2.147235
# 2         Europe   1.580226    5.45         -3.869774
# 3  North America   5.257716    7.99         -2.732284
# 4  South America  10.400000    3.50          6.900000
# 5        Oceania   3.240268    0.60          2.640268

# %%
dfgdp = pd.read_csv('gdp.csv')

# %%
list[dfgdp]

# %%
print(gdp.columns)

# %%
gdp.describe()

# %%
# Inspect the exact column names
print(dfgdp.columns.tolist())

# %%
# Define the columns to keep: "Country Name", "Code", and years 2000 to 2020
columns_to_keep = ['Country Name', 'Code'] + [str(year) for year in range(2000, 2021)]

# Ensure the dataset contains these columns
filtered_dfgdp = dfgdp[columns_to_keep]

# Save the filtered data to the current directory
output_file_path = 'filtered_dfgdp_2000_2020.csv'  # Save in the current working directory
filtered_dfgdp.to_csv(output_file_path, index=False)

# %%
gdp = pd.read_csv('filtered_dfgdp_2000_2020.csv', index_col = 0)
gdp

# %%
# First dataset: Waste shares
waste_data = {
    'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    'Share of waste recycled from total regional waste': [3.7033863, 3.985935, 4.2745633, 4.564884, 4.8600082, 5.150596, 5.4449744, 5.7405467, 6.0234685, 6.3141065, 6.6227803, 6.9352217, 7.2388344, 7.537689, 7.836343, 8.164696, 8.450203, 8.747166, 9.036769, 9.292344],
    'Share of waste incinerated from total regional waste': [10.872603, 11.335858, 11.796122, 12.255621, 12.712106, 13.169611, 13.623553, 14.075386, 14.530793, 14.980321, 15.421236, 15.873149, 16.3224, 16.779276, 17.219267, 17.625141, 18.084925, 18.57843, 19.083899, 19.048033],
    'Share of littered and mismanaged from total regional waste': [26.019512, 26.0388, 26.058777, 26.044748, 26.01943, 25.952034, 25.881447, 25.787539, 25.611216, 25.44969, 25.310413, 25.125038, 24.887909, 24.610676, 24.388899, 24.083096, 23.626896, 23.1996, 22.697952, 22.45448],
    'Share of waste landfilled from total regional waste': [59.4045, 58.6394, 57.870537, 57.134747, 56.408455, 55.72776, 55.050026, 54.396534, 53.834515, 53.255886, 52.645576, 52.06659, 51.550865, 51.072365, 50.555504, 50.12707, 49.837975, 49.474804, 49.18138, 49.205143],
}

# Second dataset: Plastic production in hundred million kg
plastic_data = {
    'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    'plastic_production': [213000000, 218000000, 231000000, 241000000, 256000000, 263000000, 280000000, 295000000, 281000000, 288000000, 313000000, 325000000, 338000000, 352000000, 367000000, 381000000, 400050000, 420052500, 441055140, 459746020]
}

# Convert datasets to pandas DataFrames
waste_df = pd.DataFrame(waste_data)
plastic_df = pd.DataFrame(plastic_data)

# Merge the two datasets on 'year'
merged_df = pd.merge(waste_df, plastic_df, on='year')

# Calculate the exact amount of plastic in each category
merged_df['recycled_plastic'] = merged_df['plastic_production'] * merged_df['Share of waste recycled from total regional waste'] / 100
merged_df['incinerated_plastic'] = merged_df['plastic_production'] * merged_df['Share of waste incinerated from total regional waste'] / 100
merged_df['mismanaged_plastic'] = merged_df['plastic_production'] * merged_df['Share of littered and mismanaged from total regional waste'] / 100
merged_df['landfilled_plastic'] = merged_df['plastic_production'] * merged_df['Share of waste landfilled from total regional waste'] / 100

# Display the results: Exact amounts for each category
result_df = merged_df[['year', 'recycled_plastic', 'incinerated_plastic', 'mismanaged_plastic', 'landfilled_plastic']]
print(result_df)

# %%
# Plotting the line graph for the plastic waste management categories
plt.figure(figsize=(10, 6))

# Plotting each category as a line
plt.plot(merged_df['year'], merged_df['recycled_plastic'], label='Recycled', marker='o')
plt.plot(merged_df['year'], merged_df['incinerated_plastic'], label='Incinerated', marker='s')
plt.plot(merged_df['year'], merged_df['mismanaged_plastic'], label='Mismanaged', marker='^')
plt.plot(merged_df['year'], merged_df['landfilled_plastic'], label='Landfilled', marker='x')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Plastic Waste (hundred millions kg)')
plt.title('Exact amount of Plastic Waste Management Over Time (2000-2019)')
plt.legend(title="Categories", bbox_to_anchor=(1, 1), loc='upper left')

# Set x-axis ticks to be the actual years
plt.xticks(merged_df['year'], rotation=45)

# Show grid for better readability
plt.grid(False)

# Show the plot
plt.tight_layout()
plt.show()
